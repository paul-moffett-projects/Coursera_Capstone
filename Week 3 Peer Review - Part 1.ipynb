# %% [markdown]
# # Capstone Project Week 3 - Almost There ;)
#
# ## Data scraping, data frame construction, data exploration, segmentation and clustering

# %%
import pandas as pd
import requests
import re

from bs4 import BeautifulSoup
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20181101100342-0000

# %%
# Get the neighborhood table from the wiki: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

neighborhoodDataWikiUrl = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
neighborhoodDataRequest  = requests.get(neighborhoodDataWikiUrl)

neighborhoodDataSource = neighborhoodDataRequest.text
neighborhoodDataSoup = BeautifulSoup(neighborhoodDataSource, "lxml")

neighborhoodTableRaw = neighborhoodDataSoup.find('table', attrs={'class':'wikitable'})
neighborhoodTableRows = neighborhoodTableRaw.find_all('tr')
neighborhoodTableHeaders = neighborhoodTableRaw.find_all('th')

# First construct a dictionary that will be used to create the data frame. The Keys will be the row headers and the values will be lists 
# for example {'Postcode': [], 'Borough': [], 'Neighbourhood': []} etc
#
# This dictionary will need cleaned later to remove any data we don't want
neighborhoodDataDict = {}

# Add the headers as the dictionary keys 
for headerTag in neighborhoodTableHeaders:
    
    headerRawString = headerTag.string
    
    # The last header has a newline char, we want to remove this to keep everything neat and working
    headerRawStriped = headerRawString.strip()
    
    # Add the header as a key to the dictionary by assigning the header as an empty list into the dictionary
    neighborhoodDataDict[headerRawStriped] = []

# Debug/testing
# print(neighborhoodDataDict)
# print()

# Now add each of the table values into the related lists, skipping the first item in the list as this is the headers
for rowTag in neighborhoodTableRows[1:]:
    
    # Add the rows tableData to the related dictionary locations
    tdSet = rowTag.find_all('td')
    
    rowPostcodeTag = tdSet[0]
    rowBoroughTag = tdSet[1]
    rowNeighbourhoodTag = tdSet[2]

    # The tags for each row may have links, this will make the value embeded deeper into the tag   
    aSetPostcode = rowPostcodeTag.find_all('a')
    aSetBorough = rowBoroughTag.find_all('a')
    aSetNeighbourhood = rowNeighbourhoodTag.find_all('a')
    
    Postcode = rowPostcodeTag.string.strip() if not aSetPostcode else aSetPostcode[0].string.strip()
    Borough = rowBoroughTag.string.strip() if not aSetBorough else aSetBorough[0].string.strip()
    Neighbourhood = rowNeighbourhoodTag.string.strip() if not aSetNeighbourhood else aSetNeighbourhood[0].string.strip()
    
    # Housekeeping as per assignment rules
    if ( Borough == 'Not assigned' ): 
        # Skip this row
        continue
    
    # Add the rows to the dictionary
    neighborhoodDataDict['Postcode'].append(Postcode)
    neighborhoodDataDict['Borough'].append(Borough)
    neighborhoodDataDict['Neighbourhood'].append(Neighbourhood)

# Create the dataFrame
dataFrameRaw = pd.DataFrame.from_dict(neighborhoodDataDict)

# Housekeeping, combining multiple neighbourhoods for postcodes 
dataFrameCleanGroup = dataFrameRaw.groupby(['Postcode', 'Neighbourhood'])
dataFrameClean = dataFrameCleanGroup.agg('min')

print(dataFrameClean.to_string())
# Out:
#                                                                     Borough
# Postcode Neighbourhood
# M1B      Malvern                                                Scarborough
#          Rouge                                                  Scarborough
# M1C      Highland Creek                                         Scarborough
#          Port Union                                             Scarborough
#          Rouge Hill                                             Scarborough
# M1E      Guildwood                                              Scarborough
#          Morningside                                            Scarborough
#          West Hill                                              Scarborough
# M1G      Woburn                                                 Scarborough
# M1H      Cedarbrae                                              Scarborough
# M1J      Scarborough Village                                    Scarborough
# M1K      East Birchmount Park                                   Scarborough
#          Ionview                                                Scarborough
#          Kennedy Park                                           Scarborough
# M1L      Clairlea                                               Scarborough
#          Golden Mile                                            Scarborough
#          Oakridge                                               Scarborough
# M1M      Cliffcrest                                             Scarborough
#          Cliffside                                              Scarborough
#          Scarborough Village West                               Scarborough
# M1N      Birch Cliff                                            Scarborough
#          Cliffside West                                         Scarborough
# M1P      Dorset Park                                            Scarborough
#          Scarborough Town Centre                                Scarborough
#          Wexford Heights                                        Scarborough
# M1R      Maryvale                                               Scarborough
#          Wexford                                                Scarborough
# M1S      Agincourt                                              Scarborough
# M1T      Clarks Corners                                         Scarborough
#          Sullivan                                               Scarborough
#          Tam O'Shanter                                          Scarborough
# M1V      Agincourt North                                        Scarborough
#          L'Amoreaux East                                        Scarborough
#          Milliken                                               Scarborough
#          Steeles East                                           Scarborough
# M1W      L'Amoreaux West                                        Scarborough
#          Steeles West                                           Scarborough
# M1X      Upper Rouge                                            Scarborough
# M2H      Hillcrest Village                                       North York
# M2J      Fairview                                                North York
#          Henry Farm                                              North York
#          Oriole                                                  North York
# M2K      Bayview Village                                         North York
# M2L      Silver Hills                                            North York
#          York Mills                                              North York
# M2M      Newtonbrook                                             North York
#          Willowdale                                              North York
# M2N      Willowdale South                                        North York
# M2P      York Mills West                                         North York
# M2R      Willowdale West                                         North York
# M3A      Parkwoods                                               North York
# M3B      Don Mills North                                         North York
# M3C      Don Mills South                                         North York
#          Flemingdon Park                                         North York
# M3H      Bathurst Manor                                          North York
#          Downsview North                                         North York
#          Wilson Heights                                          North York
# M3J      Northwood Park                                          North York
#          York University                                         North York
# M3K      CFB Toronto                                             North York
#          Downsview East                                          North York
# M3L      Downsview West                                          North York
# M3M      Downsview Central                                       North York
# M3N      Downsview Northwest                                     North York
# M4A      Victoria Village                                        North York
# M4B      Parkview Hill                                            East York
#          Woodbine Gardens                                         East York
# M4C      Woodbine Heights                                         East York
# M4E      The Beaches                                           East Toronto
# M4G      Leaside                                                  East York
# M4H      Thorncliffe Park                                         East York
# M4J      East Toronto                                             East York
# M4K      Riverdale                                             East Toronto
#          The Danforth West                                     East Toronto
# M4L      India Bazaar                                          East Toronto
#          The Beaches West                                      East Toronto
# M4M      Studio District                                       East Toronto
# M4N      Lawrence Park                                      Central Toronto
# M4P      Davisville North                                   Central Toronto
# M4R      North Toronto West                                 Central Toronto
# M4S      Davisville                                         Central Toronto
# M4T      Moore Park                                         Central Toronto
#          Summerhill East                                    Central Toronto
# M4V      Deer Park                                          Central Toronto
#          Forest Hill SE                                     Central Toronto
#          Rathnelly                                          Central Toronto
#          South Hill                                         Central Toronto
#          Summerhill West                                    Central Toronto
# M4W      Rosedale                                          Downtown Toronto
# M4X      Cabbagetown                                       Downtown Toronto
#          St. James Town                                    Downtown Toronto
# M4Y      Church and Wellesley                              Downtown Toronto
# M5A      Harbourfront                                      Downtown Toronto
#          Regent Park                                       Downtown Toronto
# M5B      Garden District                                   Downtown Toronto
#          Ryerson                                           Downtown Toronto
# M5C      St. James Town                                    Downtown Toronto
# M5E      Berczy Park                                       Downtown Toronto
# M5G      Central Bay Street                                Downtown Toronto
# M5H      Adelaide                                          Downtown Toronto
#          King                                              Downtown Toronto
#          Richmond                                          Downtown Toronto
# M5J      Harbourfront East                                 Downtown Toronto
#          Toronto Islands                                   Downtown Toronto
#          Union Station                                     Downtown Toronto
# M5K      Design Exchange                                   Downtown Toronto
#          Toronto Dominion Centre                           Downtown Toronto
# M5L      Commerce Court                                    Downtown Toronto
#          Victoria Hotel                                    Downtown Toronto
# M5M      Bedford Park                                            North York
#          Lawrence Manor East                                     North York
# M5N      Roselawn                                           Central Toronto
# M5P      Forest Hill North                                  Central Toronto
#          Forest Hill West                                   Central Toronto
# M5R      North Midtown                                      Central Toronto
#          The Annex                                          Central Toronto
#          Yorkville                                          Central Toronto
# M5S      Harbord                                           Downtown Toronto
#          University of Toronto                             Downtown Toronto
# M5T      Chinatown                                         Downtown Toronto
#          Grange Park                                       Downtown Toronto
#          Kensington Market                                 Downtown Toronto
# M5V      Bathurst Quay                                     Downtown Toronto
#          CN Tower                                          Downtown Toronto
#          Harbourfront West                                 Downtown Toronto
#          Island airport                                    Downtown Toronto
#          King and Spadina                                  Downtown Toronto
#          Railway Lands                                     Downtown Toronto
#          South Niagara                                     Downtown Toronto
# M5W      Stn A PO Boxes 25 The Esplanade                   Downtown Toronto
# M5X      First Canadian Place                              Downtown Toronto
#          Underground city                                  Downtown Toronto
# M6A      Lawrence Heights                                        North York
#          Lawrence Manor                                          North York
# M6B      Glencairn                                               North York
# M6C      Humewood-Cedarvale                                            York
# M6E      Caledonia-Fairbanks                                           York
# M6G      Christie                                          Downtown Toronto
# M6H      Dovercourt Village                                    West Toronto
#          Dufferin                                              West Toronto
# M6J      Little Portugal                                       West Toronto
#          Trinity                                               West Toronto
# M6K      Brockton                                              West Toronto
#          Exhibition Place                                      West Toronto
#          Parkdale Village                                      West Toronto
# M6L      Maple Leaf Park                                         North York
#          North Park                                              North York
#          Upwood Park                                             North York
# M6M      Del Ray                                                       York
#          Keelsdale                                                     York
#          Mount Dennis                                                  York
#          Silverthorn                                                   York
# M6N      Runnymede                                                     York
#          The Junction North                                            York
# M6P      High Park                                             West Toronto
#          The Junction South                                    West Toronto
# M6R      Parkdale                                              West Toronto
#          Roncesvalles                                          West Toronto
# M6S      Runnymede                                             West Toronto
#          Swansea                                               West Toronto
# M7A      Not assigned                                          Queen's Park
# M7R      Canada Post Gateway Processing Centre                  Mississauga
# M7Y      Business reply mail Processing Centre969 Eastern      East Toronto
# M8V      Humber Bay Shores                                        Etobicoke
#          Mimico South                                             Etobicoke
#          New Toronto                                              Etobicoke
# M8W      Alderwood                                                Etobicoke
#          Long Branch                                              Etobicoke
# M8X      Montgomery Road                                          Etobicoke
#          Old Mill North                                           Etobicoke
#          The Kingsway                                             Etobicoke
# M8Y      Humber Bay                                               Etobicoke
#          King's Mill Park                                         Etobicoke
#          Kingsway Park South East                                 Etobicoke
#          Mimico NE                                                Etobicoke
#          Old Mill South                                           Etobicoke
#          Royal York South East                                    Etobicoke
#          Sunnylea                                                 Etobicoke
#          The Queensway East                                       Etobicoke
# M8Z      Kingsway Park South West                                 Etobicoke
#          Mimico NW                                                Etobicoke
#          Royal York South West                                    Etobicoke
#          South of Bloor                                           Etobicoke
#          The Queensway West                                       Etobicoke
# M9A      Islington Avenue                                         Etobicoke
# M9B      Cloverdale                                               Etobicoke
#          Islington                                                Etobicoke
#          Martin Grove                                             Etobicoke
#          Princess Gardens                                         Etobicoke
#          West Deane Park                                          Etobicoke
# M9C      Bloordale Gardens                                        Etobicoke
#          Eringate                                                 Etobicoke
#          Markland Wood                                            Etobicoke
#          Old Burnhamthorpe                                        Etobicoke
# M9L      Humber Summit                                           North York
# M9M      Emery                                                   North York
#          Humberlea                                               North York
# M9N      Weston                                                        York
# M9P      Westmount                                                Etobicoke
# M9R      Kingsview Village                                        Etobicoke
#          Martin Grove Gardens                                     Etobicoke
#          Richview Gardens                                         Etobicoke
#          St. Phillips                                             Etobicoke
# M9V      Albion Gardens                                           Etobicoke
#          Beaumond Heights                                         Etobicoke
#          Humbergate                                               Etobicoke
#          Jamestown                                                Etobicoke
#          Mount Olive                                              Etobicoke
#          Silverstone                                              Etobicoke
#          South Steeles                                            Etobicoke
#          Thistletown                                              Etobicoke
# M9W      Northwest                                                Etobicoke

# %%
print(dataFrameClean.shape)
# Out:
# (212, 1)
